# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

#Rename column "name" in school_data to "school name"
school_data.rename({"name":"school name"}, axis=1, inplace=True)
copy_school_sum=school_data.copy()

#Rename column "school" in student_data to "school name"
rename_student_data=student_data.rename(columns={"school":"school name"})


# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
total_schools=school_data["school_name"].count()
total_students=rename_student_data["school_name"].count()
total_budget=school_data["budget"].sum()

avg_math_score=rename_student_data["math_score"].mean()
avg_read_score=rename_student_data["reading_score"].mean()

math_pass=rename_student_data.loc[(student_data["math_score"]>=70)]
count_pass_math=math_pass["math_score"].count()
per_math_pass=(count_pass_math/total_students)*100

read_pass=rename_student_data.loc[(student_data["reading_score"]>=70)]
count_pass_read=read_pass["reading_score"].count()
per_read_pass=(count_pass_read/total_students)*100

overall_pass=(per_math_pass + per_read_pass)/2

district_summary={"Total Schools": total_schools,
                 "Total Students": total_students,
                 "Total Budget": total_budget,
                 "Average Math Score": avg_math_score,
                 "Average Reading Score": avg_read_score,
                 "% Passing Math": per_math_pass,
                 "% Passing Reading": per_read_pass,
                 "% Overall Passing": overall_pass
                 }

district_summary_data=pd.DataFrame([district_summary])

district_summary_data=district_summary_data[["Total Schools",
                                            "Total Students", "Total Budget", "Average Math Score", "Average Reading Score",
                                            "% Passing Math", "% Passing Reading", "% Overall Passing"
                                            ]]

district_summary_data
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          80.393158

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
copy_school_sum
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
copy_school_sum.set_index('School ID')
# Out:
#                      school_name      type  size   budget
# School ID
# 0              Huang High School  District  2917  1910635
# 1           Figueroa High School  District  2949  1884411
# 2            Shelton High School   Charter  1761  1056600
# 3          Hernandez High School  District  4635  3022020
# 4            Griffin High School   Charter  1468   917500
# 5             Wilson High School   Charter  2283  1319574
# 6            Cabrera High School   Charter  1858  1081356
# 7             Bailey High School  District  4976  3124928
# 8             Holden High School   Charter   427   248087
# 9               Pena High School   Charter   962   585858
# 10            Wright High School   Charter  1800  1049400
# 11         Rodriguez High School  District  3999  2547363
# 12           Johnson High School  District  4761  3094650
# 13              Ford High School  District  2739  1763916
# 14            Thomas High School   Charter  1635  1043130

# %%
copy_school_sum['Per Student Budget']=copy_school_sum['budget']/copy_school_sum['size']

avg_math_read_tbl=rename_student_data.groupby(['school_name'])['reading_score','math_score'].mean().reset_index()

copy_school_sum=copy_school_sum.merge(avg_math_read_tbl,on='school_name', how="outer")

summary_passing_read=rename_student_data[rename_student_data['reading_score']>=70]

summary_passing_math=rename_student_data[rename_student_data['math_score']>=70]

pass_read_count_sum=summary_passing_read.groupby(["school_name"])['reading_score'].count().reset_index()

pass_read_count_sum.rename({'reading_score': 'Reading Count'},axis=1, inplace=True)

pass_math_count_sum=summary_passing_read.groupby(["school_name"])['math_score'].count().reset_index()

pass_math_count_sum.rename({'math_score': 'Math Count'},axis=1, inplace=True)

pass_count=pass_math_count_sum.merge(pass_read_count_sum, on="school_name", how='inner')

copy_school_sum=copy_school_sum.merge(pass_count, on="school_name", how='outer')

copy_school_sum['% Passing Math']=(copy_school_sum['Math Count']/copy_school_sum['size'])*100

copy_school_sum['% Passing Reading']=(copy_school_sum['Reading Count']/copy_school_sum['size'])*100

del copy_school_sum['Math Count']
del copy_school_sum['Reading Count']

copy_school_sum['% Overall Passing']=(copy_school_sum['% Passing Math'] + copy_school_sum['% Passing Reading'])/2

copy_school_sum.rename({'reading_score': 'Avg. Reading Score',
                            'math_score':'Avg. Math Score'}, axis=1, inplace=True)

# %%
copy_school_sum
# Out:
#     School ID            school_name      type  size   budget  \
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
top_performing_by_pr_data=copy_school_sum.sort_values(by=['% Overall Passing'], ascending=False).head(5)

top_performing_by_pr_data.head(5)
# Out:
#     School ID          school_name     type  size   budget  \
# 14         14   Thomas High School  Charter  1635  1043130
# 4           4  Griffin High School  Charter  1468   917500
# 6           6  Cabrera High School  Charter  1858  1081356
# 10         10   Wright High School  Charter  1800  1049400
# 5           5   Wilson High School  Charter  2283  1319574
#
#     Per Student Budget  reading_score_x  math_score_x  reading_score_y  \
# 14               638.0        83.848930     83.418349        83.848930
# 4                625.0        83.816757     83.351499        83.816757
# 6                582.0        83.975780     83.061895        83.975780
# 10               583.0        83.955000     83.682222        83.955000
# 5                578.0        83.989488     83.274201        83.989488
#
#     math_score_y  % Passing Math  % Passing Reading  % Overall Passing  \
# 14     83.418349       97.308869          97.308869          97.308869
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
worst_performing_by_pr_data=copy_school_sum.sort_values(by=['% Overall Passing']).head(5)

worst_performing_by_pr_data.head(5)
# Out:
#     School ID            school_name      type  size   budget  \
# 13         13       Ford High School  District  2739  1763916
# 11         11  Rodriguez High School  District  3999  2547363
# 1           1   Figueroa High School  District  2949  1884411
# 3           3  Hernandez High School  District  4635  3022020
# 12         12    Johnson High School  District  4761  3094650
#
#     Per Student Budget  reading_score_x  math_score_x  reading_score_y  \
# 13               644.0        80.746258     77.102592        80.746258
# 11               637.0        80.744686     76.842711        80.744686
# 1                639.0        81.158020     76.711767        81.158020
# 3                652.0        80.934412     77.289752        80.934412
# 12               650.0        80.966394     77.072464        80.966394
#
#     math_score_y  % Passing Math  % Passing Reading  % Overall Passing  \
# 13     77.102592       79.299014          79.299014          79.299014
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
math_scores_by_grade_data=pivot_table(student_data,values=['math_score'],
                                                        index=['school_name'],
                                                        columns=['grade'])

math_scores_by_grade_data=math_scores_by_grade_data.reindex(labels=['9th',
                                                                        '10th',
                                                                        '11th',
                                                                        '12th'],
                                                                        axis=1, level=1)
math_scores_by_grade_data
# Out:
#                       math_score
# grade                        9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
read_scores_by_grade_data=pivot_table(student_data,values=['reading_score'], 
                                                        index=['school_name'],
                                                        columns=['grade'])

read_scores_by_grade_data=read_scores_by_grade_data.reindex(labels=['9th',
                                                                        '10th',
                                                                        '11th',
                                                                        '12th'],
                                                                        axis=1, level=1)
read_scores_by_grade_data
# Out:
#                       reading_score
# grade                           9th       10th       11th       12th
# school_name
# Bailey High School        81.303155  80.907183  80.945643  80.912451
# Cabrera High School       83.676136  84.253219  83.788382  84.287958
# Figueroa High School      81.198598  81.408912  80.640339  81.384863
# Ford High School          80.632653  81.262712  80.403642  80.662338
# Griffin High School       83.369193  83.706897  84.288089  84.013699
# Hernandez High School     80.866860  80.660147  81.396140  80.857143
# Holden High School        83.677165  83.324561  83.815534  84.698795
# Huang High School         81.290284  81.512386  81.417476  80.305983
# Johnson High School       81.260714  80.773431  80.616027  81.227564
# Pena High School          83.807273  83.612000  84.335938  84.591160
# Rodriguez High School     80.993127  80.629808  80.864811  80.376426
# Shelton High School       84.122642  83.441964  84.373786  82.781671
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
scores_by_school_spending=copy_school_sum.copy()

spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

bins_school_spending=pd.cut(scores_by_school_spending['Per Student Budget'],
    spending_bins,labels=group_names)

bins_school_spending=pd.DataFrame(bins_school_spending)

copy_school_sum['bins_school_spending']=bins_school_spending

# %%
copy_school_sum.columns
copy_school_sum.groupby(['bins_school_spending']).mean()
# Out:
#                       School ID         size        budget  \
# bins_school_spending
# $585-615               5.500000  1361.500000  8.212290e+05
# $615-645               8.333333  2961.000000  1.880208e+06
# $645-675               5.000000  4104.333333  2.675768e+06
# <$585                  7.250000  1592.000000  9.246042e+05
#
#                       Per Student Budget  reading_score_x  math_score_x  \
# bins_school_spending
# $585-615                      604.500000        83.885211     83.599686
# $615-645                      635.166667        81.891436     79.079225
# $645-675                      652.333333        81.027843     76.997210
# <$585                         581.000000        83.933814     83.455399
#
#                       reading_score_y  math_score_y  % Passing Math  \
# bins_school_spending
# $585-615                    83.885211     83.599686       95.900287
# $615-645                    81.891436     79.079225       86.106569
# ...

# %%
scores_by_school_spending=copy_school_sum.groupby(['bins_school_spending'])['Avg. Reading Score'].mean()

# %%
scores_by_school_spending
# Out:
# bins_school_spending
# $585-615              Avg. Reading Score    83.885211
#                       Avg. Reading Score    83.885211
# $615-645              Avg. Reading Score    81.891436
#                       Avg. Reading Score    81.891436
# $645-675              Avg. Reading Score    81.027843
#                       Avg. Reading Score    81.027843
# <$585                 Avg. Reading Score    83.933814
#                       Avg. Reading Score    83.933814
# Name: Avg. Reading Score, dtype: float64

# %%
scores_by_school_spending=copy_school_sum.groupby(['bins_school_spending'])['Avg. Math Score'].mean()

# %%
scores_by_school_spending
# Out:
# bins_school_spending
# $585-615              Avg. Math Score    83.599686
#                       Avg. Math Score    83.599686
# $615-645              Avg. Math Score    79.079225
#                       Avg. Math Score    79.079225
# $645-675              Avg. Math Score    76.997210
#                       Avg. Math Score    76.997210
# <$585                 Avg. Math Score    83.455399
#                       Avg. Math Score    83.455399
# Name: Avg. Math Score, dtype: float64

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
scores_by_school_size=copy_school_sum.copy()

# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
bins_school_size=pd.cut(scores_by_school_size['size'], bins, labels=size_labels)

bins_school_size=pd.DataFrame(bins_school_size)

copy_school_sum['School Population']=bins_school_size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-c159bcccabdc> in <module>
# ----> 1 bins_school_size=cut(scores_by_school_size['size'], bins, labels=size_labels)
#       2
#       3 bins_school_size=pd.DataFrame(bins_school_size)
#       4
#       5 copy_school_sum['School Population']=bins_school_size
#
# NameError: name 'bins' is not defined

# %%
scores_by_school_size=copy_school_sum.groupby(['School Population', 'school name'])['Avg. Reading Score',
                                                                                   'Avg. Math Score',
                                                                                   '% Passing Reading',
                                                                                   '% Passing Math',
                                                                                   '% Overall Passing',
                                                                                   ].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-b53213e07010> in <module>
# ----> 1 scores_by_school_size=copy_school_sum.groupby(['School Population', 'school name'])['Avg. Reading Score',
#       2                                                                                    'Avg. Math Score',
#       3                                                                                    '% Passing Reading',
#       4                                                                                    '% Passing Math',
#       5                                                                                    '% Overall Passing',
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
# ...

# %%
scores_by_school_size
# Out:
#     School ID            school_name      type  size   budget  \
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %% [markdown]
# ## Scores by School Type

# %%
scores_by_school_type=copy_school_sum.copy()

scores_by_schol_type=pd.DataFrame(scores_by_school_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-55c80d4dbd1d> in <module>
# ----> 1 scores_by_school_type=copy_school_sum.copy()
#       2
#       3 scores_by_schol_type=pd.DataFrame(scores_by_school_type)
#
# NameError: name 'copy_school_sum' is not defined

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
scores_by_school_type=copy_school_sum.groupby(['type'])['Avg. Reading Score',
                                                      'Avg. Math Score',
                                                      '% Passing Reading',
                                                      '% Passing Math',
                                                      '% Overall Passing',
                                                      ].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-be07e90d6e6a> in <module>
# ----> 1 scores_by_school_type=copy_school_sum.groupby(['type'])['Avg. Reading Score',
#       2                                                       'Avg. Math Score',
#       3                                                       '% Passing Reading',
#       4                                                       '% Passing Math',
#       5                                                       '% Overall Passing',
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     255                 bad_keys = list(set(key).difference(self.obj.columns))
#     256                 raise KeyError("Columns not found: {missing}"
# --> 257                                .format(missing=str(bad_keys)[1:-1]))
#     258             return self._gotitem(list(key), ndim=2)
# ...

# %%
scores_by_school_type.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4e9d4a320787> in <module>
# ----> 1 scores_by_school_type.head()
#
# NameError: name 'scores_by_school_type' is not defined
